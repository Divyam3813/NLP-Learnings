# %%
words=["eating","eats","eaten","writing","writes","programming","programs","history","finally","finalized"]

# %% [markdown]
# PorterStemmer

# %%
from nltk.stem import PorterStemmer

# %%
stemming=PorterStemmer()

# %%
for word in words:
    print(word+"------>"+stemming.stem(word))
# Out:
# eating------>eat
# eats------>eat
# eaten------>eaten
# writing------>write
# writes------>write
# programming------>program
# programs------>program
# history------>histori
# finally------>final
# finalized------>final

# %%
stemming.stem('congratulations')
# Out:
# 'congratul'

# %%
stemming.stem('fairly')
# Out:
# 'fairli'

# %% [markdown]
# RegexStemmer

# %%
from nltk.stem import RegexpStemmer

# %%
reg_stemmer=RegexpStemmer('ing$|es$|e$|able$', min=4) ## Min means apply this on word length >=4

# %%
for word in words:
    print(word+"------>"+reg_stemmer.stem(word))
# Out:
# eating------>eat
# eats------>eats
# eaten------>eaten
# writing------>writ
# writes------>writ
# programming------>programm
# programs------>programs
# history------>history
# finally------>finally
# finalized------>finalized

# %% [markdown]
# Snowball Stemmer

# %%
from nltk.stem import SnowballStemmer

# %%
snowballstemmer=SnowballStemmer('english')

# %%
words=["Fairly","Sportingly"]

# %%
for word in words2:
    print(word+"------>"+snowballstemmer.stem(word))
# Out:
# Fairly------>fair
# Sportingly------>sport

# %%
snowballstemmer.stem('goes')
# Out:
# 'goe'
